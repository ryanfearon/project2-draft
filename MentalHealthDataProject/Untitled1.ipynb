# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
rds_connection_string = "postgres:delilahjones@localhost:5432/mentalhealth_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
df = pd.read_sql("select * from mental_health", con = engine)

# %%
df
# Out:
#       year  tech_company employer_benefits know_options  \
# 0     2019          True      I don't know           No
# 1     2019          True               Yes           No
# 2     2019          True      I don't know           No
# 3     2019          True      I don't know           No
# 4     2019          True      I don't know           No
# ...    ...           ...               ...          ...
# 1306  2017          True               Yes          Yes
# 1307  2017         False      I don't know           No
# 1308  2017          True      I don't know           No
# 1309  2017          True               Yes           No
# 1310  2017          True               Yes          Yes
#
#      employer_discussed_benefits employer_resources     anonymity  \
# 0                            Yes                Yes  I don't know
# 1                             No                Yes           Yes
# 2                             No       I don't know  I don't know
# 3                            Yes                Yes           Yes
# 4                   I don't know       I don't know  I don't know
# ...                          ...                ...           ...
# 1306                          No                 No           Yes
# 1307                          No                 No  I don't know
# 1308                          No       I don't know           Yes
# 1309                I don't know                 No           Yes
# 1310                          No                 No            No
#
#         difficulty_leave comfortable_discussing  employer_discussed_issues  \
# 0              Very easy                    Yes                      False
# 1           I don't know                  Maybe                      False
# 2     Somewhat difficult                     No                      False
# 3              Very easy                    Yes                      False
# 4           I don't know                     No                      False
# ...                  ...                    ...                        ...
# 1306       Somewhat easy                    Yes                       True
# 1307           Difficult                     No                      False
# 1308           Very easy                    Yes                      False
# 1309           Very easy                    Yes                       True
# 1310           Very easy                    Yes                       True
#
#       physical_importance  mental_importance  industry_support  age gender  \
# 0                       5                  5                 4   25      M
# 1                       5                  7                 1   51      M
# 2                       5                  4                 2   27      M
# 3                       1                  3                 3   37      M
# 4                       4                  4                 3   46      M
# ...                   ...                ...               ...  ...    ...
# 1306                    4                  5                 4   29      M
# 1307                    7                  0                 1   38      M
# 1308                    6                  6                 3   41      M
# 1309                    8                  4                 3   40      M
# 1310                    6                  4                 2   30      M
#
#                        country
# 0     United States of America
# 1     United States of America
# 2     United States of America
# 3     United States of America
# 4     United States of America
# ...                        ...
# 1306  United States of America
# 1307  United States of America
# 1308            United Kingdom
# 1309  United States of America
# 1310  United States of America
#
# [1311 rows x 16 columns]
