# %%
# Import Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# Read in CSVs
df1 = pd.read_csv("Resources/OSMI 2019 Mental Health in Tech Survey Results.csv")
df2 = pd.read_csv("Resources/OSMI 2020 Mental Health in Tech Survey Results cleaned.csv")
df3 = pd.read_csv("Resources/OSMI Mental Health in Tech Survey 2018.csv")
df4 = pd.read_csv("Resources/OSMI Mental Health in Tech Survey 2017.csv")
df5 = pd.read_csv("Resources/OSMI Mental Health in Tech 2016 Survey Results.csv")

# %%
# Merge CSVs
final_df = pd.concat([df1,df2,df3,df4,df5]).reset_index(drop=True)
final_df = final_df.dropna()
final_df.to_csv("mergedmentalhealth.csv",index=False)
final_df
# Out:
#       year  tech_company employer_benefits know_options  \
# 0     2019          True      I don't know           No
# 1     2019          True               Yes           No
# 2     2019          True      I don't know           No
# 3     2019          True      I don't know           No
# 4     2019          True      I don't know           No
# ...    ...           ...               ...          ...
# 1458  2017          True               Yes          Yes
# 1459  2017         False      I don't know           No
# 1460  2017          True      I don't know           No
# 1461  2017          True               Yes           No
# 1462  2017          True               Yes          Yes
#
#      employer_discussed_benefits employer_resources     anonymity  \
# 0                            Yes                Yes  I don't know
# 1                             No                Yes           Yes
# 2                             No       I don't know  I don't know
# 3                            Yes                Yes           Yes
# 4                   I don't know       I don't know  I don't know
# ...                          ...                ...           ...
# 1458                          No                 No           Yes
# 1459                          No                 No  I don't know
# 1460                          No       I don't know           Yes
# 1461                I don't know                 No           Yes
# 1462                          No                 No            No
#
#         difficulty_leave comfortable_discussing employer_discussed_issues  \
# 0              Very easy                    Yes                     False
# 1           I don't know                  Maybe                     False
# 2     Somewhat difficult                     No                     False
# 3              Very easy                    Yes                     False
# 4           I don't know                     No                     False
# ...                  ...                    ...                       ...
# 1458       Somewhat easy                    Yes                      True
# 1459           Difficult                     No                     False
# 1460           Very easy                    Yes                     False
# 1461           Very easy                    Yes                      True
# 1462           Very easy                    Yes                      True
#
#       physical_importance  mental_importance  industry_support  age gender  \
# 0                     5.0                5.0               4.0   25      M
# 1                     5.0                7.0               1.0   51      M
# 2                     5.0                4.0               2.0   27      M
# 3                     1.0                3.0               3.0   37      M
# 4                     4.0                4.0               3.0   46      M
# ...                   ...                ...               ...  ...    ...
# 1458                  4.0                5.0               4.0   29      M
# 1459                  7.0                0.0               1.0   38      M
# 1460                  6.0                6.0               3.0   41      M
# 1461                  8.0                4.0               3.0   40      M
# 1462                  6.0                4.0               2.0   30      M
#
#                        country
# 0     United States of America
# 1     United States of America
# 2     United States of America
# 3     United States of America
# 4     United States of America
# ...                        ...
# 1458  United States of America
# 1459  United States of America
# 1460            United Kingdom
# 1461  United States of America
# 1462  United States of America
#
# [1311 rows x 16 columns]

# %%
# Create database connection
# change the owner name, password and port number based on your local situation
# engine = create_engine(f'postgresql://{*database_owner}:{*password}@localhost:{*port}/housing_db')
rds_connection_string = "postgres:delilahjones@localhost:5432/mentalhealth_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# <ipython-input-19-2d97e9123e98>:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['mental_health']

# %%
# Load dataframes into databases
final_df.to_sql(name = 'mental_health', con = engine, if_exists = 'append', index = False)

# %%
# Confirm data has been added by querying the income_tax table
pd.read_sql_query('select * from mental_health', con=engine).head()
# Out:
#    year  tech_company employer_benefits know_options  \
# 0  2019          True      I don't know           No
# 1  2019          True               Yes           No
# 2  2019          True      I don't know           No
# 3  2019          True      I don't know           No
# 4  2019          True      I don't know           No
#
#   employer_discussed_benefits employer_resources     anonymity  \
# 0                         Yes                Yes  I don't know
# 1                          No                Yes           Yes
# 2                          No       I don't know  I don't know
# 3                         Yes                Yes           Yes
# 4                I don't know       I don't know  I don't know
#
#      difficulty_leave comfortable_discussing employer_discussed_issues  \
# 0           Very easy                    Yes                     False
# 1        I don't know                  Maybe                     False
# 2  Somewhat difficult                     No                     False
# 3           Very easy                    Yes                     False
# 4        I don't know                     No                     False
#
#    physical_importance  mental_importance  industry_support  age gender  \
# 0                  5.0                5.0               4.0   25      M
# 1                  5.0                7.0               1.0   51      M
# 2                  5.0                4.0               2.0   27      M
# 3                  1.0                3.0               3.0   37      M
# 4                  4.0                4.0               3.0   46      M
#
#                     country
# 0  United States of America
# 1  United States of America
# 2  United States of America
# 3  United States of America
# 4  United States of America
