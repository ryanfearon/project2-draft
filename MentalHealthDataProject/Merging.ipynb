# %%
# Import Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# Read in CSVs
df1 = pd.read_csv("OSMI 2019 Mental Health in Tech Survey Results.csv")
df2 = pd.read_csv("OSMI 2020 Mental Health in Tech Survey Results cleaned.csv")
df3 = pd.read_csv("OSMI Mental Health in Tech Survey 2018.csv")
df4 = pd.read_csv("OSMI Mental Health in Tech Survey 2017.csv")
df5 = pd.read_csv("OSMI Mental Health in Tech 2016 Survey Results.csv")

# %%
# Merge CSVs
final_df = pd.concat([df1,df2,df3,df4,df5]).reset_index(drop=True)
final_df.to_csv("mergedmentalhealth.csv",index=False)
final_df
# Out:
#       year  tech_company employer_benefits   know_options  \
# 0     2019          True      I don't know             No
# 1     2019          True               Yes             No
# 2     2019          True      I don't know             No
# 3     2019          True      I don't know             No
# 4     2019          True      I don't know             No
# ...    ...           ...               ...            ...
# 2604  2016          True      I don't know  I am not sure
# 2605  2016          True               Yes             No
# 2606  2016          True               Yes            Yes
# 2607  2016         False      I don't know  I am not sure
# 2608  2016          True               Yes             No
#
#      employer_discussed_benefits employer_resources     anonymity  \
# 0                            Yes                Yes  I don't know
# 1                             No                Yes           Yes
# 2                             No       I don't know  I don't know
# 3                            Yes                Yes           Yes
# 4                   I don't know       I don't know  I don't know
# ...                          ...                ...           ...
# 2604                          No       I don't know  I don't know
# 2605                          No                 No           Yes
# 2606                         Yes                Yes  I don't know
# 2607                          No                Yes  I don't know
# 2608                          No                 No  I don't know
#
#         difficulty_leave comfortable_discussing employer_discussed_issues  \
# 0              Very easy                    Yes                     False
# 1           I don't know                  Maybe                     False
# 2     Somewhat difficult                     No                     False
# 3              Very easy                    Yes                     False
# 4           I don't know                     No                     False
# ...                  ...                    ...                       ...
# 2604       Somewhat easy                  Maybe                       NaN
# 2605       Somewhat easy                    Yes                       NaN
# 2606  Somewhat difficult                    Yes                       NaN
# 2607  Somewhat difficult                    Yes                       NaN
# 2608      Very difficult                  Maybe                       NaN
#
#       physical_importance  mental_importance  industry_support  age gender  \
# 0                     5.0                5.0               4.0   25      M
# 1                     5.0                7.0               1.0   51      M
# 2                     5.0                4.0               2.0   27      M
# 3                     1.0                3.0               3.0   37      M
# 4                     4.0                4.0               3.0   46      M
# ...                   ...                ...               ...  ...    ...
# 2604                  NaN                NaN               NaN   26      F
# 2605                  NaN                NaN               NaN   38      F
# 2606                  NaN                NaN               NaN   52      M
# 2607                  NaN                NaN               NaN   30      F
# 2608                  NaN                NaN               NaN   25     NB
#
#                        country
# 0     United States of America
# 1     United States of America
# 2     United States of America
# 3     United States of America
# 4     United States of America
# ...                        ...
# 2604                    Canada
# 2605  United States of America
# 2606  United States of America
# 2607  United States of America
# 2608                    Canada
#
# [2609 rows x 16 columns]

# %%
# Create database connection
# change the owner name, password and port number based on your local situation
# engine = create_engine(f'postgresql://{*database_owner}:{*password}@localhost:{*port}/housing_db')
rds_connection_string = "postgres:postgres@localhost:5433/mentalhealth_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['mental_health']

# %%
# Load dataframes into databases
final_df.to_sql(name = 'mental_health', con = engine, if_exists = 'append', index = False)

# %%
# Confirm data has been added by querying the income_tax table
pd.read_sql_query('select * from mental_health', con=engine).head()
# Out:
#    year  tech_company employer_benefits know_options  \
# 0  2019          True      I don't know           No
# 1  2019          True               Yes           No
# 2  2019          True      I don't know           No
# 3  2019          True      I don't know           No
# 4  2019          True      I don't know           No
#
#   employer_discussed_benefits employer_resources     anonymity  \
# 0                         Yes                Yes  I don't know
# 1                          No                Yes           Yes
# 2                          No       I don't know  I don't know
# 3                         Yes                Yes           Yes
# 4                I don't know       I don't know  I don't know
#
#      difficulty_leave comfortable_discussing employer_discussed_issues  \
# 0           Very easy                    Yes                     False
# 1        I don't know                  Maybe                     False
# 2  Somewhat difficult                     No                     False
# 3           Very easy                    Yes                     False
# 4        I don't know                     No                     False
#
#    physical_importance  mental_importance  industry_support  age gender  \
# 0                  5.0                5.0               4.0   25      M
# 1                  5.0                7.0               1.0   51      M
# 2                  5.0                4.0               2.0   27      M
# 3                  1.0                3.0               3.0   37      M
# 4                  4.0                4.0               3.0   46      M
#
#                     country
# 0  United States of America
# 1  United States of America
# 2  United States of America
# 3  United States of America
# 4  United States of America
